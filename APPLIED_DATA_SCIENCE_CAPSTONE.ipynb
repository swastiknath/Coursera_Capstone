# %% [markdown]
# <h1>IBM APPLIED DATA SCIENCE CAPSTONE PROJECT</h1>
# <p>This project is an integral part of the IBM Data Science Professional Certificate. This project is where we will apply our creative skills and the acquired skills of data science throughout the session.</p>
#     <h3> Beginning the Journey: </h3>

# %%
import numpy as np
import pandas as pd
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
